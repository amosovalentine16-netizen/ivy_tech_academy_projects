# %%
print("="*50)
print("Welcome to The Data Calculator")
print("="*50)
# Out:
# ==================================================
# Welcome to The Data Calculator
# ==================================================

# %%
#Ask the user to enter the first and second numbers,then input operators
first_number=float(input("Enter first number:"))
second_number=float(input("Enter second number:"))
operator=input("Enter operator(+,-,*,/):")
if operator=="+":
    result=first_number+second_number
elif operator=="-":
     result=first_number-second_number
elif operator=="*":
     result=first_number*second_number
elif operatr=="/":
    if second_number!=0:
         result=first_number/second_number
    else:
        result="Error"
else:
    result="Operation error"
print("Result:", result)
# Out:
# Enter first number: 30
# Enter second number: 5
# Enter operator(+,-,*,/): +
# Result: 35.0
